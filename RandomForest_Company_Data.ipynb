# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Company_Data.csv')

# %%
data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
data.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
data.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
data['Sales'].isna().sum()
# Out:
# 0

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Sales, CompPrice, Income, Advertising, Population, Price, ShelveLoc, Age, Education, Urban, US]
# Index: []

# %%
data.head(176)

#sales value of 174th row is 0 ,lets drop that row
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 171  12.49         93     106           12         416     55    Medium   75
# 172   9.03        104     102           13         123    110      Good   35
# 173   6.38        135      91            5         207    128    Medium   66
# 174   0.00        139      24            0         358    185    Medium   79
# 175   7.54        115      89            0          38    122    Medium   25
#
#      Education Urban   US
# ...

# %%
data =data.drop(index=174).reset_index(drop=True)

# %%
sns.histplot(data.Sales);
# Target column is normally distributed

# %%
sns.histplot(data['Advertising'])
# Out:
# <Axes: xlabel='Advertising', ylabel='Count'>

# %%
sns.histplot(data['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data['CompPrice'])
# Out:
# <Axes: xlabel='CompPrice', ylabel='Count'>

# %%
sns.histplot(data['Education'])
# Out:
# <Axes: xlabel='Education', ylabel='Count'>

# %%
sns.histplot(data['Income'])
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
sns.histplot(data['Population'])
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
sns.histplot(data['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
# Histogram of categorical data

# %%
sns.histplot(data['ShelveLoc']);data['ShelveLoc'].value_counts()
# Out:
# Medium    218
# Bad        96
# Good       85
# Name: ShelveLoc, dtype: int64

# %%
sns.histplot(data['Urban']);data['Urban'].value_counts()
# Out:
# Yes    282
# No     117
# Name: Urban, dtype: int64

# %%
sns.histplot(data['US']);data['US'].value_counts()
# Out:
# Yes    258
# No     141
# Name: US, dtype: int64

# %%
sns.scatterplot(x=data['Advertising'],y=data['Sales'],data=data)
# Out:
# <Axes: xlabel='Advertising', ylabel='Sales'>

# %%
sns.scatterplot(x=data['Age'],y=data['Sales'],data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Sales'>

# %%
sns.scatterplot(x=data['CompPrice'],y=data['Sales'],data=data)
# Out:
# <Axes: xlabel='CompPrice', ylabel='Sales'>

# %%
    sns.scatterplot(x=data['Education'],y=data['Sales'],data=data)
# Out:
# <Axes: xlabel='Education', ylabel='Sales'>

# %%
sns.scatterplot(x=data['Income'],y=data['Sales'],data=data)
# Out:
# <Axes: xlabel='Income', ylabel='Sales'>

# %%
sns.scatterplot(x=data['Population'],y=data['Sales'],data=data)
# Out:
# <Axes: xlabel='Population', ylabel='Sales'>

# %%
sns.scatterplot(x=data['Price'],y=data['Sales'],data=data)
# Out:
# <Axes: xlabel='Price', ylabel='Sales'>

# %%
sns.scatterplot(x=data['ShelveLoc'],y=data['Sales'],data=data)
# Out:
# <Axes: xlabel='ShelveLoc', ylabel='Sales'>

# %%
sns.scatterplot(x=data['US'],y=data['Sales'],data=data)
# Out:
# <Axes: xlabel='US', ylabel='Sales'>

# %%
sns.scatterplot(x=data['Urban'],y=data['Sales'],data=data)
# Out:
# <Axes: xlabel='Urban', ylabel='Sales'>

# %%
sns.pairplot(data,palette='mako',hue='ShelveLoc')

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=data, orient="h");

# %%
data.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.070883  0.143035     0.265543    0.055205 -0.433956
# CompPrice    0.070883   1.000000 -0.077315    -0.021957   -0.096309  0.585053
# Income       0.143035  -0.077315  1.000000     0.055241   -0.005362 -0.045616
# Advertising  0.265543  -0.021957  0.055241     1.000000    0.267706  0.052495
# Population   0.055205  -0.096309 -0.005362     0.267706    1.000000 -0.016978
# Price       -0.433956   0.585053 -0.045616     0.052495   -0.016978  1.000000
# Age         -0.223937  -0.104320  0.001695    -0.000587   -0.045347 -0.115424
# Education   -0.049608   0.024263 -0.055362    -0.032590   -0.107122  0.008760
#
#                   Age  Education
# Sales       -0.223937  -0.049608
# CompPrice   -0.104320   0.024263
# Income       0.001695  -0.055362
# Advertising -0.000587  -0.032590
# Population  -0.045347  -0.107122
# Price       -0.115424   0.008760
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
# Multivariate 
sns.scatterplot(y=data['Sales'],x=data['Price'],hue=data['Advertising'])
# Out:
# <Axes: xlabel='Price', ylabel='Sales'>

# %% [markdown]
# # Encoding the categoricals variables

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
data['ShelveLoc'] = LE.fit_transform(data['ShelveLoc'])
data['Urban'] = LE.fit_transform(data['Urban'])
data['US'] = LE.fit_transform(data['US'])

# %%
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120          0   42
# 1  11.22        111      48           16         260     83          1   65
# 2  10.06        113      35           10         269     80          2   59
# 3   7.40        117     100            4         466     97          2   55
# 4   4.15        141      64            3         340    128          0   38
#
#    Education  Urban  US
# 0         17      1   1
# 1         10      1   1
# 2         12      1   1
# 3         14      1   1
# 4         13      1   0

# %%
data.Sales.mean(),data.Sales.max()
# Out:
# (7.515112781954888, 16.27)

# %%
sns.histplot(data.Sales)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %% [markdown]
# # Converting Sales column into the categories for the better prediction

# %%
bins = [0,5.39,9.32,17]
labels = ['Low',"Mid",'High']
sales_ctg = pd.cut(data['Sales'],bins=bins,labels=labels)
sales_ctg = pd.DataFrame(sales_ctg)
data1 = pd.DataFrame(data.drop(columns='Sales'))
data1['Sales_Cat'] = sales_ctg
data1
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120          0   42
# 1          111      48           16         260     83          1   65
# 2          113      35           10         269     80          2   59
# 3          117     100            4         466     97          2   55
# 4          141      64            3         340    128          0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 394        138     108           17         203    128          1   33
# 395        139      23            3          37    120          2   55
# 396        162      26           12         368    159          2   40
# 397        100      79            7         284     95          0   50
# 398        134      37            0          27    120          1   49
#
#      Education  Urban  US Sales_Cat
# 0           17      1   1      High
# 1           10      1   1      High
# ...

# %%
data1[data1['Sales_Cat'].isnull()]
# Out:
# Empty DataFrame
# Columns: [CompPrice, Income, Advertising, Population, Price, ShelveLoc, Age, Education, Urban, US, Sales_Cat]
# Index: []

# %%
data.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.070883  0.143035     0.265543    0.055205 -0.433956
# CompPrice    0.070883   1.000000 -0.077315    -0.021957   -0.096309  0.585053
# Income       0.143035  -0.077315  1.000000     0.055241   -0.005362 -0.045616
# Advertising  0.265543  -0.021957  0.055241     1.000000    0.267706  0.052495
# Population   0.055205  -0.096309 -0.005362     0.267706    1.000000 -0.016978
# Price       -0.433956   0.585053 -0.045616     0.052495   -0.016978  1.000000
# ShelveLoc    0.164616   0.021482 -0.064609     0.010649   -0.046155  0.008631
# Age         -0.223937  -0.104320  0.001695    -0.000587   -0.045347 -0.115424
# Education   -0.049608   0.024263 -0.055362    -0.032590   -0.107122  0.008760
# Urban       -0.026025   0.070427  0.031975     0.038327   -0.049747  0.059169
# US           0.170010   0.020029  0.084668     0.683497    0.062877  0.068644
#
# ...

# %%
sns.heatmap(data1.corr())
# Out:
# <Axes: >

# %% [markdown]
# # Encoding the Sales column

# %%
data2 = pd.DataFrame(data1)
data2['Sales_enc'] = LE.fit_transform(data1.Sales_Cat)
data2.drop('Sales_Cat',axis=1,inplace=True)
data2
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120          0   42
# 1          111      48           16         260     83          1   65
# 2          113      35           10         269     80          2   59
# 3          117     100            4         466     97          2   55
# 4          141      64            3         340    128          0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 394        138     108           17         203    128          1   33
# 395        139      23            3          37    120          2   55
# 396        162      26           12         368    159          2   40
# 397        100      79            7         284     95          0   50
# 398        134      37            0          27    120          1   49
#
#      Education  Urban  US  Sales_enc
# 0           17      1   1          0
# 1           10      1   1          0
# ...

# %%
X = data1.iloc[:,:-2]

# %%
X
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120          0   42
# 1          111      48           16         260     83          1   65
# 2          113      35           10         269     80          2   59
# 3          117     100            4         466     97          2   55
# 4          141      64            3         340    128          0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 394        138     108           17         203    128          1   33
# 395        139      23            3          37    120          2   55
# 396        162      26           12         368    159          2   40
# 397        100      79            7         284     95          0   50
# 398        134      37            0          27    120          1   49
#
#      Education  Urban  US
# 0           17      1   1
# 1           10      1   1
# 2           12      1   1
# ...

# %%
Y = data['Sales']

# %%
Y
y1 = data1['Sales_enc']
y1
# Out:
# 0      0
# 1      0
# 2      0
# 3      2
# 4      1
#       ..
# 394    0
# 395    2
# 396    2
# 397    2
# 398    0
# Name: Sales_enc, Length: 399, dtype: int32

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y1,test_size=0.2,random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((319, 10), (80, 10), (319,), (80,))

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn import ensemble
model = ensemble.RandomForestClassifier(random_state=42)

# %% [markdown]
# # Hyper parameters tuning

# %%
parameters = [{'n_estimators':[20,40,60,80,100],'max_depth':[5,10,15,20]},{'n_estimators':[20,30,40,60,100], 'max_depth': 
             [5,10,15],'max_features':[2,5,8,10]}]

# %% [markdown]
# # Grid Search CV

# %%
grid_search = GridSearchCV(estimator=model,param_grid=parameters,n_jobs=-1,cv=10)

# %%
grid = grid_search.fit(X_train,y_train)

# %%
grid.best_score_
# Out:
# 0.7207661290322581

# %%
grid.best_params_
# We got best score at max_depth': 15, 'max_features': 10, 'n_estimators': 30
# Out:
# {'max_depth': 15, 'max_features': 10, 'n_estimators': 100}

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
rf = ensemble.RandomForestClassifier(max_depth=15,max_features=10)
dt = DecisionTreeClassifier(max_depth=15,max_features=10)

# %%
model1 = rf.fit(X_train,y_train)

# %%
model2 = dt.fit(X_train,y_train)

# %%
test_data=pd.DataFrame({'CompPrice':115,'Income':50,'Advertising':5,'Population':290,'Price':5,'ShelveLoc':4,'Age':51,'Education':14,'Urban':0,'US':1},index=[1])
test_data
# Out:
#    CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 1        115      50            5         290      5          4   51
#
#    Education  Urban  US
# 1         14      0   1

# %%
data1['Sales_Cat'].value_counts()
# Out:
# Mid     201
# Low      99
# High     99
# Name: Sales_Cat, dtype: int64

# %%
data1['Sales_enc'].value_counts()
# Out:
# 2    201
# 0     99
# 1     99
# Name: Sales_enc, dtype: int64

# %%
model1.predict(test_data)
# It says test data has 'Low' sales
# Out:
# array([0])

# %%
train_pred = model1.predict(X_train)
test_pred = model1.predict(X_test)

# %%
#Lets make Decision tree of this model at max_depth': 15, 'max_features': 10, 'n_estimators': 30

# %%
plt.figure(figsize=(10,8),dpi=200);
plot_tree(model2,feature_names=X.columns,filled=True,max_depth=3);

# %%
# Decision tree shows us that the model is more dependent on Shelveloc and Price column

# %% [markdown]
# # Random Search CV

# %%
random_search = RandomizedSearchCV(estimator=model,param_distributions=parameters,n_jobs=-1,cv = 10)

# %%
random = random_search.fit(X_train,y_train)

# %%
random.best_score_
# Grid bestCv did give better score
# Out:
# 0.6894153225806452

# %%
random.best_params_
# Out:
# {'n_estimators': 60, 'max_features': 10, 'max_depth': 10}

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
rf1 = ensemble.RandomForestClassifier(max_depth=10,max_features=10)
dt1 = DecisionTreeClassifier(max_depth=10,max_features=10)
model3 = rf1.fit(X_train,y_train)

# %%
test_data1=pd.DataFrame({'CompPrice':190,'Income':150,'Advertising':45,'Population':98,'Price':545,'ShelveLoc':1,'Age':89,'Education':14,'Urban':0,'US':1},index=[1])
test_data1
# Out:
#    CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 1        190     150           45          98    545          1   89
#
#    Education  Urban  US
# 1         14      0   1

# %%
model3.predict(test_data1)
# It says test data has 'MID' sales
# Out:
# array([2])

# %% [markdown]
# # Classification Report

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.64      0.68        22
#            1       0.73      0.65      0.69        17
#            2       0.72      0.80      0.76        41
#
#     accuracy                           0.73        80
#    macro avg       0.73      0.70      0.71        80
# weighted avg       0.73      0.72      0.72        80

# %%
# Classification report on test data
