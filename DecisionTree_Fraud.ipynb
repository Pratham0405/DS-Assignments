# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
fraud_data = pd.read_csv('Fraud_check.csv')

# %%
fraud_data
# Out:
#     Undergrad Marital.Status  Taxable.Income  City.Population  \
# 0          NO         Single           68833            50047
# 1         YES       Divorced           33700           134075
# 2          NO        Married           36925           160205
# 3         YES         Single           50190           193264
# 4          NO        Married           81002            27533
# ..        ...            ...             ...              ...
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      Work.Experience Urban
# 0                 10   YES
# 1                 18   YES
# 2                 30   YES
# 3                 15   YES
# 4                 28    NO
# ..               ...   ...
# 595                7   YES
# 596                2   YES
# 597                0   YES
# 598               17    NO
# 599               16    NO
#
# [600 rows x 6 columns]

# %%
data = fraud_data.iloc[:,[0,1,3,4,5,2]]

# %%
data
# Out:
#     Undergrad Marital.Status  City.Population  Work.Experience Urban  \
# 0          NO         Single            50047               10   YES
# 1         YES       Divorced           134075               18   YES
# 2          NO        Married           160205               30   YES
# 3         YES         Single           193264               15   YES
# 4          NO        Married            27533               28    NO
# ..        ...            ...              ...              ...   ...
# 595       YES       Divorced            39492                7   YES
# 596       YES       Divorced            55369                2   YES
# 597        NO       Divorced           154058                0   YES
# 598       YES        Married           180083               17    NO
# 599        NO       Divorced           158137               16    NO
#
#      Taxable.Income
# 0             68833
# 1             33700
# 2             36925
# 3             50190
# 4             81002
# ..              ...
# 595           76340
# 596           69967
# 597           47334
# 598           98592
# 599           96519
#
# [600 rows x 6 columns]

# %%
Status = []
for i in data['Taxable.Income']:
    if i <= 30000:
        Status.append("Risky")
    else :
        Status.append('Good')

# %%
data['Status'] = Status

# %%
data.describe()
# Out:
#        City.Population  Work.Experience  Taxable.Income
# count       600.000000       600.000000      600.000000
# mean     108747.368333        15.558333    55208.375000
# std       49850.075134         8.842147    26204.827597
# min       25779.000000         0.000000    10003.000000
# 25%       66966.750000         8.000000    32871.500000
# 50%      106493.500000        15.000000    55074.500000
# 75%      150114.250000        24.000000    78611.750000
# max      199778.000000        30.000000    99619.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Undergrad        600 non-null    object
#  1   Marital.Status   600 non-null    object
#  2   City.Population  600 non-null    int64
#  3   Work.Experience  600 non-null    int64
#  4   Urban            600 non-null    object
#  5   Taxable.Income   600 non-null    int64
#  6   Status           600 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 32.9+ KB

# %%
data.isnull().sum()
# No null values
# Out:
# Undergrad          0
# Marital.Status     0
# City.Population    0
# Work.Experience    0
# Urban              0
# Taxable.Income     0
# Status             0
# dtype: int64

# %%
data[data.duplicated()]
# No duplicates
# Out:
# Empty DataFrame
# Columns: [Undergrad, Marital.Status, City.Population, Work.Experience, Urban, Taxable.Income, Status]
# Index: []

# %%
data.corr()
# Out:
#                  Undergrad  Marital.Status  City.Population  Work.Experience  \
# Undergrad         1.000000        0.042407         0.079579        -0.005362
# Marital.Status    0.042407        1.000000        -0.001564        -0.002213
# City.Population   0.079579       -0.001564         1.000000         0.013135
# Work.Experience  -0.005362       -0.002213         0.013135         1.000000
# Urban            -0.000267        0.064562        -0.040098        -0.094559
# Taxable.Income   -0.049232       -0.012944        -0.064387        -0.001818
# Status            0.012523        0.006081         0.012225        -0.001972
#
#                     Urban  Taxable.Income    Status
# Undergrad       -0.000267       -0.049232  0.012523
# Marital.Status   0.064562       -0.012944  0.006081
# City.Population -0.040098       -0.064387  0.012225
# Work.Experience -0.094559       -0.001818 -0.001972
# Urban            1.000000        0.070628  0.004830
# Taxable.Income   0.070628        1.000000 -0.688725
# Status           0.004830       -0.688725  1.000000

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
data['Undergrad'].value_counts(),data['Marital.Status'].value_counts(),data['Urban'].value_counts(),data['Status'].value_counts()
# Value counts of categorical columns
# Out:
# (YES    312
#  NO     288
#  Name: Undergrad, dtype: int64,
#  Single      217
#  Married     194
#  Divorced    189
#  Name: Marital.Status, dtype: int64,
#  YES    302
#  NO     298
#  Name: Urban, dtype: int64,
#  Good     476
#  Risky    124
#  Name: Status, dtype: int64)

# %%
data
# Out:
#     Undergrad Marital.Status  City.Population  Work.Experience Urban  \
# 0          NO         Single            50047               10   YES
# 1         YES       Divorced           134075               18   YES
# 2          NO        Married           160205               30   YES
# 3         YES         Single           193264               15   YES
# 4          NO        Married            27533               28    NO
# ..        ...            ...              ...              ...   ...
# 595       YES       Divorced            39492                7   YES
# 596       YES       Divorced            55369                2   YES
# 597        NO       Divorced           154058                0   YES
# 598       YES        Married           180083               17    NO
# 599        NO       Divorced           158137               16    NO
#
#      Taxable.Income Status
# 0             68833   Good
# 1             33700   Good
# 2             36925   Good
# 3             50190   Good
# 4             81002   Good
# ..              ...    ...
# 595           76340   Good
# 596           69967   Good
# 597           47334   Good
# 598           98592   Good
# 599           96519   Good
#
# [600 rows x 7 columns]

# %% [markdown]
# # Encoding the Categorical columns

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Status'] = le.fit_transform(data['Status'])
data['Undergrad'] = le.fit_transform(data['Undergrad'])
data['Urban'] = le.fit_transform(data['Urban'])
data['Marital.Status'] = le.fit_transform(data['Marital.Status'])

# %%
data
# Out:
#      Undergrad  Marital.Status  City.Population  Work.Experience  Urban  \
# 0            0               2            50047               10      1
# 1            1               0           134075               18      1
# 2            0               1           160205               30      1
# 3            1               2           193264               15      1
# 4            0               1            27533               28      0
# ..         ...             ...              ...              ...    ...
# 595          1               0            39492                7      1
# 596          1               0            55369                2      1
# 597          0               0           154058                0      1
# 598          1               1           180083               17      0
# 599          0               0           158137               16      0
#
#      Taxable.Income  Status
# 0             68833       0
# 1             33700       0
# 2             36925       0
# 3             50190       0
# 4             81002       0
# ..              ...     ...
# 595           76340       0
# 596           69967       0
# 597           47334       0
# 598           98592       0
# 599           96519       0
#
# [600 rows x 7 columns]

# %%
data['Status'].value_counts()
# Out:
# 0    476
# 1    124
# Name: Status, dtype: int64

# %%
X = data.iloc[:,:-2]
Y = data['Status']

# %%
X
# Out:
#      Undergrad  Marital.Status  City.Population  Work.Experience  Urban
# 0            0               2            50047               10      1
# 1            1               0           134075               18      1
# 2            0               1           160205               30      1
# 3            1               2           193264               15      1
# 4            0               1            27533               28      0
# ..         ...             ...              ...              ...    ...
# 595          1               0            39492                7      1
# 596          1               0            55369                2      1
# 597          0               0           154058                0      1
# 598          1               1           180083               17      0
# 599          0               0           158137               16      0
#
# [600 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y,random_state=42,test_size=0.2)

# %% [markdown]
# # DT using Entropy criterion

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(criterion='entropy',random_state=42,max_depth=10)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((480, 5), (120, 5), (480,), (120,))

# %%
y_train
# Out:
# 145    0
# 9      0
# 375    0
# 523    0
# 188    1
#       ..
# 71     0
# 106    1
# 270    0
# 435    0
# 102    0
# Name: Status, Length: 480, dtype: int32

# %%
model = dt.fit(x_train,y_train)

# %%
train_pred = model.predict(x_train)
test_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_train,train_pred)
# Out:
# 0.8479166666666667

# %%
accuracy_score(y_test,test_pred)
# Out:
# 0.7583333333333333

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10,8),dpi=400);
plot_tree(model,feature_names=X.columns,filled=True);

# %% [markdown]
# # Lets check the model accuracy using Gini criterion

# %%
from sklearn.tree import DecisionTreeClassifier
dt1 = DecisionTreeClassifier(criterion='gini',random_state=42,max_depth=10)

# %%
model1 = dt1.fit(x_train,y_train)

train_pred1 = model1.predict(x_train)
test_pred1 = model1.predict(x_test)

# %%
accuracy_score(y_train,train_pred1)
# Out:
# 0.8979166666666667

# %%
accuracy_score(y_test,test_pred1)
# Out:
# 0.7166666666666667

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10,8),dpi=400);
plot_tree(model1,feature_names=X.columns,filled=True);

# %%
test_data =pd.DataFrame({'Undergrad':0,'Marital.Status':2,'City.Population':17000,'Work.Experience':20,'Urban':1},index=[1])
test_data
# Out:
#    Undergrad  Marital.Status  City.Population  Work.Experience  Urban
# 1          0               2            17000               20      1

# %%
model.predict(test_data)
# Out:
# array([0])

# %% [markdown]
# # It says the test data is 'Risky'
