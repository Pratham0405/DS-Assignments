# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
salary_data = pd.read_csv('SalaryData_Train.csv')
salary_data
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
salary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
salary_data.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  30161.000000  30161.000000  30161.000000  30161.000000  30161.000000
# mean      38.438115     10.121316   1092.044064     88.302311     40.931269
# std       13.134830      2.550037   7406.466611    404.121321     11.980182
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
salary_data.nunique()
# Out:
# age               72
# workclass          7
# education         16
# educationno       16
# maritalstatus      7
# occupation        14
# relationship       6
# race               5
# sex                2
# capitalgain      118
# capitalloss       90
# hoursperweek      94
# native            40
# Salary             2
# dtype: int64

# %%
salary_data
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
salary_data['Salary'].value_counts()
# Out:
#  <=50K    22653
#  >50K      7508
# Name: Salary, dtype: int64

# %%
salary_data.nunique()
# Out:
# age               72
# workclass          7
# education         16
# educationno       16
# maritalstatus      7
# occupation        14
# relationship       6
# race               5
# sex                2
# capitalgain      118
# capitalloss       90
# hoursperweek      94
# native            40
# Salary             2
# dtype: int64

# %%
#Encoding the categorical columns

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
salary_data['Salary'] = le.fit_transform(salary_data['Salary'])
salary_data['workclass'] = le.fit_transform(salary_data['workclass'])
salary_data['education'] = le.fit_transform(salary_data['education'])
salary_data['maritalstatus'] = le.fit_transform(salary_data['maritalstatus'])
salary_data['occupation'] = le.fit_transform(salary_data['occupation'])
salary_data['relationship'] = le.fit_transform(salary_data['relationship'])
salary_data['race'] = le.fit_transform(salary_data['race'])
salary_data['sex'] = le.fit_transform(salary_data['sex'])
salary_data['native'] = le.fit_transform(salary_data['native'])
salary_data
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
# Scaling the continuous columns
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
salary_data['capitalgain'] = ms.fit_transform(salary_data['capitalgain'].values.reshape(-1,1))
salary_data['capitalloss'] = ms.fit_transform(salary_data['capitalloss'].values.reshape(-1,1))
salary_data['hoursperweek'] = ms.fit_transform(salary_data['hoursperweek'].values.reshape(-1,1))

# %%
salary_data
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
salary_data.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
colours = ['#000099', '#ffff00'] 
pal = sns.color_palette(colours)
sns.heatmap(salary_data.isnull(), cmap=pal)
plt.show()

# %%
salary_data.corr()
# Out:
#                     age  workclass  education  educationno  maritalstatus  \
# age            1.000000   0.080537  -0.001091     0.043525      -0.276363
# workclass      0.080537   1.000000   0.017864     0.037833      -0.034235
# education     -0.001091   0.017864   1.000000     0.345420      -0.040704
# educationno    0.043525   0.037833   0.345420     1.000000      -0.063419
# maritalstatus -0.276363  -0.034235  -0.040704    -0.063419       1.000000
# occupation    -0.005682   0.015572  -0.038213     0.087717       0.022655
# relationship  -0.246452  -0.067414  -0.012732    -0.091935       0.177955
# race           0.023380   0.044734   0.011139     0.032805      -0.068641
# sex            0.081972   0.074966  -0.027831     0.006155      -0.119774
# capitalgain    0.080152   0.035349   0.030582     0.124416      -0.042414
# capitalloss    0.060278   0.007244   0.014822     0.079691      -0.035385
# hoursperweek   0.101598   0.050723   0.059892     0.152522      -0.189004
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(salary_data.corr(), cmap='winter', annot=True)
plt.plot()
# Out:
# []

# %%
sns.countplot(x='Salary',data= salary_data)
plt.xlabel('Salary')
plt.ylabel('count')
plt.show()
salary_data['Salary'].value_counts()
# Out:
# 0    22653
# 1     7508
# Name: Salary, dtype: int64

# %%
pd.crosstab(salary_data['Salary'],salary_data['education']).mean().plot(kind='bar')
# Out:
# <Axes: xlabel='education'>

# %%
pd.crosstab(salary_data['Salary'],salary_data['occupation']).mean().plot(kind='bar')
# Out:
# <Axes: xlabel='occupation'>

# %%
pd.crosstab(salary_data['Salary'],salary_data['sex']).mean().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
pd.crosstab(salary_data['Salary'],salary_data['relationship']).mean().plot(kind='bar')
# Out:
# <Axes: xlabel='relationship'>

# %% [markdown]
# # Train Data

# %%
X_train = salary_data.iloc[:,:-1]
Y_train= salary_data['Salary']

# %%
X_train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
Y_train
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 30156    0
# 30157    1
# 30158    0
# 30159    0
# 30160    1
# Name: Salary, Length: 30161, dtype: int32

# %% [markdown]
# # Test Data

# %%
test_salary = pd.read_csv('SalaryData_Test.csv')
test_salary
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
#Encoding the categorical columns of test data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
test_salary['Salary'] = le.fit_transform(test_salary['Salary'])
test_salary['workclass'] = le.fit_transform(test_salary['workclass'])
test_salary['education'] = le.fit_transform(test_salary['education'])
test_salary['maritalstatus'] = le.fit_transform(test_salary['maritalstatus'])
test_salary['occupation'] = le.fit_transform(test_salary['occupation'])
test_salary['relationship'] = le.fit_transform(test_salary['relationship'])
test_salary['race'] = le.fit_transform(test_salary['race'])
test_salary['sex'] = le.fit_transform(test_salary['sex'])
test_salary['native'] = le.fit_transform(test_salary['native'])
test_salary
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
# Scaling the test data

test_salary['capitalgain'] = ms.fit_transform(test_salary['capitalgain'].values.reshape(-1,1))
test_salary['capitalloss'] = ms.fit_transform(test_salary['capitalloss'].values.reshape(-1,1))
test_salary['hoursperweek'] = ms.fit_transform(test_salary['hoursperweek'].values.reshape(-1,1))
test_salary
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
X_test = test_salary.iloc[:,:-1]
Y_test = test_salary['Salary']

# %%
X_test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
X_train.head(9)
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
# 5   37          2         12           14              2           3
# 6   49          2          6            5              3           7
# 7   52          4         11            9              2           3
# 8   31          2         12           14              4           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 0             1     4    1     0.021740          0.0      0.397959      37
# 1             0     4    1     0.000000          0.0      0.122449      37
# ...

# %%
from sklearn.naive_bayes import MultinomialNB,GaussianNB,CategoricalNB

# %%
# instantiating the model
model = CategoricalNB()
model1 = MultinomialNB()
model2 = GaussianNB()

# fit the model
model.fit(X_train, Y_train)
model1.fit(X_train, Y_train)
model2.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
model.fit(X_train,Y_train)
# Out:
# MultinomialNB()

# %%
model.score(X_train,Y_train),model.score(X_test,Y_test)
# Out:
# (0.806239846158947, 0.8090305444887118)

# %%
model1.score(X_train,Y_train),model1.score(X_test,Y_test)
# Out:
# (0.7363814197142005, 0.7295484727755644)

# %%
model2.score(X_train,Y_train),model2.score(X_test,Y_test)
# Out:
# (0.7976194423261829, 0.796812749003984)

# %%
salary_data['Salary'].value_counts()
# Out:
# 0    22653
# 1     7508
# Name: Salary, dtype: int64

# %%
test_data=pd.DataFrame({'age':11,'workclass' : 3,'education':12,'educationno' : 3,'maritalstatus':1,'occupation':0,'relationship':4,'race':1,'sex':1,'capitalgain': 4,'capitalloss':1,'hoursperweek':0.448980,'native':55},index=[1])

# %%
model2.predict(test_data)
#Prediction on test data is salary >50K
# Out:
# array([1])

# %%
from sklearn.metrics import accuracy_score

# %%
#Predictions
y_pred = model.predict(X_test)
y_pred1 = model1.predict(X_test)
y_pred2 = model2.predict(X_test)

print('CategoricalNB Model accuracy score: {0:0.4f}'. format(accuracy_score(Y_test, y_pred)))
print('MultinomialNB Model accuracy score: {0:0.4f}'. format(accuracy_score(Y_test, y_pred1)))
print('GaussianNB Model accuracy score: {0:0.4f}'. format(accuracy_score(Y_test, y_pred2)))
# Out:
# CategoricalNB Model accuracy score: 0.8090
# MultinomialNB Model accuracy score: 0.7295
# GaussianNB Model accuracy score: 0.7968

# %%
from sklearn.metrics import confusion_matrix,classification_report,roc_curve,roc_auc_score

# %%
# print the classification report

print('CategoricalNB Model',classification_report(Y_test, y_pred))
print('MultinomialNB Model',classification_report(Y_test, y_pred1))
print('GaussianNB Model',classification_report(Y_test, y_pred2))
# Out:
# CategoricalNB Model               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87     11360
#            1       0.59      0.76      0.66      3700
#
#     accuracy                           0.81     15060
#    macro avg       0.75      0.79      0.76     15060
# weighted avg       0.83      0.81      0.82     15060
#
# MultinomialNB Model               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81     11360
#            1       0.46      0.58      0.51      3700
#
#     accuracy                           0.73     15060
#    macro avg       0.66      0.68      0.66     15060
# weighted avg       0.76      0.73      0.74     15060
#
# GaussianNB Model               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.88     11360
#            1       0.67      0.34      0.45      3700
#
#     accuracy                           0.80     15060
# ...

# %%
#the output probability
test_proba=model.predict_proba(X_test)
test_proba
# Out:
# array([[9.99996280e-01, 3.71994278e-06],
#        [6.29773679e-01, 3.70226321e-01],
#        [2.43493457e-01, 7.56506543e-01],
#        ...,
#        [1.98133078e-02, 9.80186692e-01],
#        [9.69379509e-01, 3.06204909e-02],
#        [6.10311639e-03, 9.93896884e-01]])

# %%
test_proba[:,1]
# Out:
# array([3.71994278e-06, 3.70226321e-01, 7.56506543e-01, ...,
#        9.80186692e-01, 3.06204909e-02, 9.93896884e-01])

# %%
#false positive rate,true positive rate,threshhold
fpr1,tpr1,thresh1=roc_curve(Y_test,test_proba[:,1])

# %%
plt.plot(fpr1,tpr1)
plt.plot([0,1],[0,1],'r--')
plt.title('ROC_AUC Curve')
plt.xlabel('false positive rate(fpr)')
plt.ylabel('true negative rate(tnr)')
plt.show()

# %%
roc_auc_score(Y_test,y_pred)
# Out:
# 0.7909509421393224

# %%
# By using CategoricalNB classifier we get the best accuracy
